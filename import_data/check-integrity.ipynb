# %%
import  pandas as pd

orders = pd.read_csv("orders-f.csv")

orders["order_id"].duplicated().sum()
# Out:
# np.int64(0)

# %%
customers = pd.read_csv("customers-f.csv")

customers["customer_id"].duplicated().sum()
# Out:
# np.int64(0)

# %%
deliveries = pd.read_csv("deliveries-f.csv")

deliveries["delivery_id"].duplicated().sum()
# Out:
# np.int64(0)

# %%
orders[
    ~orders["customer_id"].isin(customers["customer_id"])
]
# Out:
# Empty DataFrame
# Columns: [order_id, customer_id, order_date, order_status, route_id, origin_city, destination_city]
# Index: []

# %%
expenses = pd.read_csv("expenses-f.csv")

expenses["amount"].dtype
# Out:
# dtype('float64')

# %%
customers["customer_phone_number"].dtype
# Out:
# dtype('int64')
